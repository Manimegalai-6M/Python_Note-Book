# %%
# types of error

#IndentationError:
#TypeError:
#SyntaxError:
#IndexError:
#ZeroDivisionError:
#NameError:S

# %%
#IndentationError:
print("helloe")
    print("jnvjn")
# Out:
#   Cell In[1], line 2
#     print("jnvjn")
#     ^
# IndentationError: unexpected indent

# %%
#TypeError:
print('a'+3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print('a'+3)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#SyntaxError:
print("kjij"):
# Out:
#   Cell In[7], line 1
#     print("kjij"):
#                  ^
# SyntaxError: invalid syntax

# %%
#IndexError:
a=[0,6,7,8]
print(a[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 a=[0,6,7,8]
# ----> 2 print(a[4])
#
# IndexError: list index out of range

# %%
#ZeroDivisionError:
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
#NameError:
print(3+x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 #NameError:
# ----> 2 print(3+x)
#
# NameError: name 'x' is not defined

# %%
#how to handle this error

# %%
a=int(input("enter the number1:"))
b=int(input("enter the number2:"))
try:
    print(" the value a divisible by b is:",a/b)
except:
    print(" the value a is not divisible by b because you are given input data is invalid input ......so check")
# Out:
# enter the number1: 10
# enter the number2: 0
#  the value a is not divisible by b because you are given input data is invalid input ......so check

# %%
a=int(input("enter the number1:"))
b=int(input("enter the number2:"))
try:
    print(" the value a divisible by b is:",a/b)
except:
    print(" the value a is not divisible by b because you are given input data is invalid input ......so check")
# Out:
# enter the number1: 10
# enter the number2: 20
#  the value a divisible by b is: 0.5

# %%
a=int(input("enter the number1:"))
b=float(input("enter the number2:"))
try:
    print(" the value a divisible by b is:",a/b)
except:
    print(" the value a is not divisible by b because you are given input data is invalid input ......so check")
# Out:
# enter the number1: 10
# enter the number2: 0.1
#  the value a divisible by b is: 100.0

# %%
a=int(input("enter the number1:"))
b=float(input("enter the number2:"))

except:
    print(" the value a is not divisible by b because you are given input data is invalid input ......so check")
# Out:
#   Cell In[25], line 4
#     except:
#     ^
# SyntaxError: invalid syntax

# %%
a=int(input("enter the number1:"))
b=float(input("enter the number2:"))
try:
    print(" the value a divisible by b is:",a/b)
# Out:
#   Cell In[24], line 4
#     print(" the value a divisible by b is:",a/b)
#                                                 ^
# SyntaxError: incomplete input

# %%
#HANDLING MULTIPLE EXCEPT BLOCK:

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError:
    print(" the value of a is not divisible by b because can not divided by zzero")
except ValueError:
    print("alphabet can not be entered")
# Out:
# enter the value1: 10
# enter the value2: 0
#  the value of a is not divisible by b because can not divided by zzero

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError:
    print(" the value of a is not divisible by b because can not divided by zzero")
except ValueError:
    print("alphabet can not be entered")
# Out:
# enter the value1: 10
# enter the value2: g
# alphabet can not be entered

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError:
    print(" the value of a is not divisible by b because can not divided by zzero")
except ValueError:
    print("alphabet can not be entered")
# Out:
# enter the value1: 30
# enter the value2: $
# alphabet can not be entered

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError:
    print(" the value of a is not divisible by b because can not divided by zzero")
except ValueError:
    print("alphabet can not be entered")
# Out:
# enter the value1: 10
# enter the value2: +
# alphabet can not be entered

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError as e:
    print(" the value of a is not divisible by b because can not divided by zzero")
except ValueError as e:
    print("alphabet can not be entered")
# Out:
# enter the value1: 10
# enter the value2: 0
#  the value of a is not divisible by b because can not divided by zzero

# %%
#give the as e is give short details error
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError as e:
    print("you are error message is:",e)
except ValueError as e:
    print("alphabet can not be entered",e)
# Out:
# enter the value1: 10
# enter the value2: 0
# you are error message is: integer division or modulo by zero

# %%
#write any letter instad of e
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError as au:
    print("you are error message is:",au)
except ValueError as au:
    print("alphabet can not be entered",au)
# Out:
# enter the value1: 90
# enter the value2: 0
# you are error message is: integer division or modulo by zero

# %%
#using two error methods in the except handling
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except (ZeroDivisionError,ValueError) as p:
    print(p)
# Out:
# enter the value1: 80
# enter the value2: 0
# integer division or modulo by zero

# %%
#using two error methods in the except handling
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except (ZeroDivisionError,ValueError) as p:
    print(p)
# Out:
# enter the value1: 70
# enter the value2: i
# invalid literal for int() with base 10: 'i'

# %%
#using system function nad it handle various error
import sys
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except:
    print(sys.exc_info()[0])
# Out:
# enter the value1: 90
# enter the value2: _
# <class 'ValueError'>

# %%
#using system function out of range in the index value it will be make the error
import sys
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except:
    print(sys.exc_info()[9])
# Out:
# enter the value1: 90
# enter the value2: _
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 5
#       4 a=int(input("enter the value1:"))
# ----> 5 b=int(input("enter the value2:"))
#       6 c=a//b
#
# ValueError: invalid literal for int() with base 10: '_'
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 8
#       6     c=a//b
#       7 except:
# ----> 8     print(sys.exc_info()[9])
#
# IndexError: tuple index out of range

# %%
#using system function give the range function
import sys
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except:
    print(sys.exc_info()[1])
# Out:
# enter the value1: 90
# enter the value2: *
# invalid literal for int() with base 10: '*'

# %%
import sys
try:
    for i in range(1,10):
        if i<20:
            print(i)
except:
    print(sys.exc_info()[1])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
import sys
try:
    for i in range(1,10):
        if i>l:
            print(i)
except:
    print(sys.exc_info()[0])
# Out:
# <class 'NameError'>

# %%
#it can not handle the syntax error
import sys
try:
    for i in range(1,10):
        if i>80i:
            print(i)
except:
    print(sys.exc_info()[0])
# Out:
#   Cell In[99], line 5
#     if i>80i:
#           ^
# SyntaxError: invalid decimal literal

# %%
import sys
try:
 a=int(input("enter the name:"))
except:
    print(sys.exc_info()[0])
# Out:
# enter the name: hgkd
# <class 'ValueError'>

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
    print1(c)
except ZeroDivisionError:
    print(" the value of a is not divisible by b because can not divided by zzero",)
except ValueError:
    print("alphabet can not be entered")
except :
    print("Error")
# Out:
# enter the value1: 10
# enter the value2: 20
# Error

# %%
try:
    a=int(input("enter the value1:"))
    b=int(input("enter the value2:"))
    c=a//b
except ZeroDivisionError:
    print(" the value of a is not divisible by b because can not divided by zzero")
except:
    print("Error")
# Out:
# enter the value1: _
# Error

# %%
#control flow of exception handling

# %%
#when no error in the code
try:
    print("hellow")
    print("2/0")
    print("bye")
except ZeroDivisionError:
    print("not divisible")
except:
    print("error")
# Out:
# hellow
# 2/0
# bye

# %%
#when there is error at try block and it is handled properly
try:
    print("hellow")
    print(2/0)
    print("bye")
except ZeroDivisionError:
    print("not divisible")
except:
    print("error")
# Out:
# hellow
# not divisible

# %%
#when there is error in try block and not handled
try:
    print1("hellow")
    print(2/0)
    print("bye")
except ZeroDivisionError:
    print("not divisible")
print("error")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 3
#       1 #when there is error in try block and not handled
#       2 try:
# ----> 3     print1("hellow")
#       4     print(2/0)
#       5     print("bye")
#
# NameError: name 'print1' is not defined

# %%
#when there is error in try block and  handled
try:
    print("hellow")
    print(2/0)
    print("bye")
except ZeroDivisionError1:
    print("not divisible")
print("error")
# Out:
# hellow
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[59], line 4
#       3 print("hellow")
# ----> 4 print(2/0)
#       5 print("bye")
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 6
#       4     print(2/0)
#       5     print("bye")
# ----> 6 except ZeroDivisionError1:
#       7     print("not divisible")
#       8 print("error")
#
# NameError: name 'ZeroDivisionError1' is not defined

# %%
try:
    print(2/0)
except ZeroDivisionError:
    print("not divisible")
except ArithmeticError:
    print("not divisible too")
# Out:
# not divisible

# %%
#because arth is parent and zero is an child first priority perform arthimetic operation
try:
    print(2/0)
except ArithmeticError:
    print("not divisible")
except ZeroDivisionError:
    print("not divisible too")
# Out:
# not divisible
