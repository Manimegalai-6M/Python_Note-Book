# %%
#find the whether a year is leap year or not

# %%
n=int(input("n:"))
if n%4==0:
    if n%100==0:
        if n%400==0:
            print("leap year")
        else:
            print("not leap year")
    else:
        print("leap year")
else:
    print("not leap year")
# Out:
# n: 1908
# leap year

# %%
n=int(input("n:"))
if n%4==0:
    print("leap year")
if (n%4==0 and n%100!=0):
    print("leap lear")
elif (n%4==0 and n%400==0):
    print("leap year")
elif (n%4==0 and n%100==0):
    print("not leap year")
else:
    print("not leap year")
# Out:
# n: 1090
# not leap year
