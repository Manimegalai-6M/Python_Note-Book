# %% [markdown]
# # CLASS & OBJECT
# class=blueprint of object
# object=many to make the object using the class(insteand of class)

# %% [markdown]
# # ATRRIBUTES & FUNCTION
# variable & methods
#
# Age      |ete
# gender   |dance
# name     |work

# %%
#syntax

class person():
# Out:
#   Cell In[46], line 3
#     class person():
#                    ^
# _IncompleteInputError: incomplete input

# %%
#class with print

class person():
    print("hai")
# Out:
# hai

# %%
class person():
    print("hai")
print(person())
# Out:
# hai
# <__main__.person object at 0x0000024368623B60>

# %%
#class with variable

class person():
    print("hai")
    a=10
    print(a)
# Out:
# hai
# 10

# %%
class person():
    print("hai")
    a=10
print(a)
# Out:
# hai
# super

# %%
class person():
    print("hai")
    a=10
obj=person()
print(obj.a)
print(type(obj))
# Out:
# hai
# 10
# <class '__main__.person'>

# %% [markdown]
# # function

# %%
def function():
    print('hello')

# %%
def function():
    print('hello')
function()
# Out:
# hello

# %%
def function():
    print('hello')
    print('everyone')
function()
# Out:
# hello
# everyone

# %%
def function():
    print('hello',end=' ')
    print('everyone')
function()  
print('hello everyoe')
function()
# Out:
# hello everyone
# hello everyoe
# hello everyone

# %%
test()
def test():
    print("i am from test")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 test()
#       2 def test():
#       3     print("i am from test")
#
# NameError: name 'test' is not defined

# %%
def test():
    print("i am from test")
test()
# Out:
# i am from test

# %%
#previous code.
def greeting():
    print(" hai. i am from function...")
greeting()
# Out:
#  hai. i am from function...

# %%
def greeting():
    print(" hai.. Neha.. Good morning")
greeting()
# Out:
#  hai.. Neha.. Good morning

# %%
def greeting():
    print(" hai.. sakthi.. Good morning")
greeting()
# Out:
#  hai.. sakthi.. Good morning

# %%
def function(name):
    print('hi',name,'how are you')
function('nivetha')
function('manimegalai')
function('sentamizh')
# Out:
# hi nivetha how are you
# hi manimegalai how are you
# hi sentamizh how are you

# %%
def fun(name='divya'):
    print('hi',name,'how are you')
fun()
# Out:
# hi divya how are you

# %%
def fun(name='divya'):
    print('hi',name,'how are you')
fun('nivetha')
# Out:
# hi nivetha how are you

# %%
def fun(name='divya'):
    print('hi',name,'how are you')
fun('nivetha')
fun()
# Out:
# hi nivetha how are you
# hi divya how are you

# %%
def add(x,y):
    z=x+y
    print('the value of z is',z)
add(10,20)
add(10,30)
# Out:
# the value of z is 30
# the value of z is 40

# %%
def fun(name):
    print('the name is',name)
def add(x,y):
    z=x+y
    print('the value of z is',z)
add(10,20)
add(10,30)
fun('manimegalai')
# Out:
# the value of z is 30
# the value of z is 40
# the name is manimegalai

# %%
def fun(x,y):
    z=x+y
    print('the value of z is',z)
def func(x,y):
    z=x-y
    print("the valus of z is",z)
fun(10,20)
func(10,20)
# Out:
# the value of z is 30
# the valus of z is -10

# %%
def add(x,y):
    z=x+y
    print("the sum is:", z)
add(10,20)
# Out:
# the sum is: 30

# %%
#add with 2 function call:
def add(x,y):
    z=x+y
    print("the sum is:", z)
add(10,20)
add(30,40)
# Out:
# the sum is: 30
# the sum is: 70

# %%
# add and sub
def add(x,y):
    z=x+y
    print("the sum is:", z)
def sub(x,y):
    z=x-y
    print("the subtracted value:", z)
add(10,20)
sub(50,20)
# Out:
# the sum is: 30
# the subtracted value: 30

# %%
def add(x,y):
    z=x+y
    print("the sum is:", z)
add(10,20)

def sub(x,y):
    z=x-y
    print("the subtracted value:", z)
sub(50,20)
# Out:
# the sum is: 30
# the subtracted value: 30

# %%
def add(x,y=3):
    z=x+y
    z1=x-y
    print(z,z1)
add(1,2)
# Out:
# 3 -1

# %%
def add(x,y=3):
    z=x+y
    z1=x-y
    return z,z1
add(1,2)
# Out:
# (3, -1)

# %%
def add(x,y=3):
    z=x+y
    z1=x-y
    return z,z1
a,b=add(1,2)
print('the value of',a)
print('the value of',b)
# Out:
# the value of 3
# the value of -1

# %%
def add(x,y=20):
    z=x+y
    print("the sum is:", z)
add(10)
# Out:
# the sum is: 30

# %%
def add(x,y=20):
    z=x+y
    print("the sum is:", z)
add(10,30)
add(10)
# Out:
# the sum is: 40
# the sum is: 30

# %%
# print outside function
def add(x,y):
    z=x+y
    print("the sum is:", z)
add(10,20)
print("the added value is:",z)
# Out:
# the sum is: 30
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[83], line 6
#       4     print("the sum is:", z)
#       5 add(10,20)
# ----> 6 print("the added value is:",z)
#
# NameError: name 'z' is not defined

# %%
def add(a,b):
    c=a+b
    print(c)
z=add(1,2)
print(z)

# %%
def add(x,y):
    z=x+y
    return z
result=add(10,20)
print("the added value is:",result)
# Out:
# the added value is: 30

# %%
def greeting():
    print("hai")
    return
    print("happy learning")
greeting()
# Out:
# hai

# %%
def greeting():
    print("hai")
    return
print("happy learning")
greeting()
# Out:
# happy learning
# hai

# %%
def greeting():
    print("hai")
    return
    print("happy learning")
    return 
greeting()
# Out:
# hai

# %%
def greeting():
    print("hai")
    print("happy learning")
    return 
greeting()
# Out:
# hai
# happy learning

# %%
def fun(x):
    return x+5
fun(10)
# Out:
# 15

# %%
#return [expression_list]
def greet(a,b):
    print(a+b)
print(greet(10,20))
# Out:
# 30
# None

# %%
#return [expression_list]
def greet(a,b):
    print(a+b)
greet(10,20)
# Out:
# 30

# %%
def greeting(x):
    print(x)
greeting("hello")
# Out:
# hello

# %%
l='l'
def f():
    print('mani',l)
f()
# Out:
# mani l

# %%
def f():
    l='l'
    print('mani',l)
f()
# Out:
# mani l

# %%
def local():
    loc_variable="i am local variable"
    print(loc_variable)
local()
print(local())
# Out:
# i am local variable
# i am local variable
# None

# %%
glo_var="hai"
def local():
    loc_variable="i am local variable"
    print(loc_variable)
    local()
    print(glo_var)

# %%
#example-global variable
glo_variable="i am global variable"
def glo():
    print("inside function:",glo_variable)
glo()
# Out:
# inside function: i am global variable

# %%
#example-local variable
def local():
    loc_variable="i am local variable"
    print(loc_variable)
local()
# Out:
# i am local variable

# %%
glo_var="hai"
def local():
    loc_variable="i am local variable"
    print(loc_variable)
local()
print(glo_var)
print(loc_variable)
# Out:
# i am local variable
# hai
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 7
#       5 local()
#       6 print(glo_var)
# ----> 7 print(loc_variable)
#
# NameError: name 'loc_variable' is not defined

# %%
#accessing within function
var="happy learning."
def greet():
    var="python series"
    print("inside function:",var)
greet()
print("outside call:",var)
# Out:
# inside function: python series
# outside call: happy learning.

# %%
var="happy learning."
def greet():
    #var="python series"
    print("inside function:",var)
greet()
print("outside call:",var)
# Out:
# inside function: happy learning.
# outside call: happy learning.

# %%
# if need to change global variable value with in function
var="happy learning."
def greet():
    global var
    var="bye bye"
    print("inside function:",var)
greet()
print("outside call:",var)
# Out:
# inside function: bye bye
# outside call: bye bye

# %%
# global and local having same name
var="happy learning."
def greet():
    var="python series"
    print("inside function:",var)
    print(globals()['var'])
    
greet()
print("outside call:",var)
# Out:
# inside function: python series
# happy learning.
# outside call: happy learning.

# %%
# global and local having same name
var="happy learning."
def greet():
    var="python series"
    print("inside function:",var)
    print(globals()['var'])
    
greet()
print("outside call:",var)
# Out:
# inside function: python series
# happy learning.
# outside call: happy learning.

# %%
# global and local having same name
var="happy learning."
def greet():
    var="python series"
    print("inside function:",var)
    
greet()
print("outside call:",var)
# Out:
# inside function: python series
# outside call: happy learning.

# %%
# global and local having same name
var="happy learning."
def greet():
    var="python series"
    print("inside function:",var)
    print(var)
    
greet()
print("outside call:",var)
# Out:
# inside function: python series
# python series
# outside call: happy learning.

# %%
var="happy learning."
def greet():
    var="python series"
    print("inside function:",var)
    globals()['var']="changed"
    print(globals()['var'])
    
greet()
print("outside call:",var)
# Out:
# inside function: python series
# changed
# outside call: changed

# %%
a="happy learning"
def c():
    a="awesome"
    print(a)
    globals()['a']="super"
    print(globals()['a'])
    print(a)
c()
print(a)
# Out:
# awesome
# super
# awesome
# super

# %%
#types of arguments
#position
#keyword
#default
#variable length

# %%
def add(x,y):
    z=x+y
    print("sum:",z)
add(5,10)
# Out:
# sum: 15

# %%
#position
def person(name,age):
    print("name is:",name)
    print("age is:",age)
person("john",23)
# Out:
# name is: john
# age is: 23

# %%
def person(name,age):
    print("name is:",name)
    print("age is:",age)
person(23,"john")
# Out:
# name is: 23
# age is: john

# %%
def person(name,age):
    print("name is:",name)
    print("age is:",age+2)
person(23,"john")
# Out:
# name is: 23
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 4
#       2     print("name is:",name)
#       3     print("age is:",age+2)
# ----> 4 person(23,"john")
#
# Cell In[113], line 3, in person(name, age)
#       1 def person(name,age):
#       2     print("name is:",name)
# ----> 3     print("age is:",age+2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
def person(name,age):
    print("name is:",name)
    print("age is:",age)
person(23,"john")

# %%
#keyword
def person(name,age):
    print("name is:",name)
    print("age is:",age+2)
person(age=23,name="john")
# Out:
# name is: john
# age is: 25

# %%
def p(name,age):
    print('the name is:',name)
    print('the age is :',age)
p(age=23,name='mani')
# Out:
# the name is: mani
# the age is : 23

# %%
def p(name,age):
    print('the name is:',name)
    print('the age is :',age+3)
p(age=23,name='mani')
# Out:
# the name is: mani
# the age is : 26

# %%
#default argument

# %%
def person(name,age):
    print("name is:",name)
    print("age is:",age)
person("john")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 4
#       2     print("name is:",name)
#       3     print("age is:",age)
# ----> 4 person("john")
#
# TypeError: person() missing 1 required positional argument: 'age'

# %%
def person(name,age=14):
    print("name is:",name)
    print("age is:",age)
person("john")
# Out:
# name is: john
# age is: 14

# %%
def person(name,age=18):
    print("name is:",name)
    print("age is:",age)
person("john")
# Out:
# name is: john
# age is: 18

# %%
def person(name,age=14):
    print("name is:",name)
    print("age is:",age)
person("john",10)
# Out:
# name is: john
# age is: 10

# %%
def person(name,age):
    print("name is:",name)
    print("age is:",age+2)
person("john",23)
# Out:
# name is: john
# age is: 25

# %%
def person(name="john",age):
    print("name is:",name)
    print("age is:",age)
person(23)
# Out:
#   Cell In[123], line 1
#     def person(name="john",age):
#                            ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def person(age,name="john"):
    print("name is:",name)
    print("age is:",age)
person(23)
# Out:
# name is: john
# age is: 23

# %%
def person(name,age=9):
    print("name is:",name)
    print("age is:",age)
person('kalai')
# Out:
# name is: kalai
# age is: 9

# %%
def person(name="john"):
    print("name is:",name)  
person()
# Out:
# name is: john

# %%
#variable length arguments
def add(x,y):
    z=x+y
    print("sum:",z)
add(10,20)
# Out:
# sum: 30

# %%
def add(x,y):
    z=x+y
    print("sum:",z)
add(10,20,30,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 4
#       2     z=x+y
#       3     print("sum:",z)
# ----> 4 add(10,20,30,40)
#
# TypeError: add() takes 2 positional arguments but 4 were given

# %%
def add(x,*y):
    z=x+y
    print("sum:",z)
add(10,20,30,40)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[130], line 4
#       2     z=x+y
#       3     print("sum:",z)
# ----> 4 add(10,20,30,40)
#
# Cell In[130], line 2, in add(x, *y)
#       1 def add(x,*y):
# ----> 2     z=x+y
#       3     print("sum:",z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def add(x,*y):
    z=x+y
    print("sum:",z)
add(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 4
#       2     z=x+y
#       3     print("sum:",z)
# ----> 4 add(10,20)
#
# Cell In[131], line 2, in add(x, *y)
#       1 def add(x,*y):
# ----> 2     z=x+y
#       3     print("sum:",z)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
def add(x,*y):
    z=x
    for i in y:
        z=z+i
    print("sum:",z)
add(10,20,30,40)
# Out:
# sum: 100

# %%
def add(x,*y):
    z=x
    for i in y:
        z=z+i
    print('sum',z)
add(1,3,8,9)
# Out:
# sum 21

# %%
def add(*y):
    z=0
    for i in y:
        z=z+i
    print("sum:",z)
add(10,20,30,40)
# Out:
# sum: 100

# %%
def add(*y):
    z=0
    for i in y:
        z=z+i
    print(z)
add(1,2,3,4)
# Out:
# 10

# %%
def person(name,age,city,ph):
    
    print("name:",name)
    print("age:",age)
    print("city:",city)
    print("ph:",ph)
person("john",43,"chennai",1234567890)
# Out:
# name: john
# age: 43
# city: chennai
# ph: 1234567890

# %%
def person(name,*values):
    print("name:",name)
    print(values)
person("john",43,"chennai",1234567890)
# Out:
# name: john
# (43, 'chennai', 1234567890)

# %%
#kwargs
# keyword variable length argument

# %%
def person(name,age,city,ph):
    
    print("name:",name)
    print("age:",age)
    print("city:",city)
    print("ph:",ph)
person("john",43,"chennai",1234567890)
# Out:
# name: john
# age: 43
# city: chennai
# ph: 1234567890

# %%
def person(name,*values):
    print("name:",name)
    print(values)
person("john",43,"chennai",1234567890)
# Out:
# name: john
# (43, 'chennai', 1234567890)

# %%
def person(name,*values):
    print("name:",name)
    print(values)
person("john",age=43,city="chennai",ph=1234567890)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2     print("name:",name)
#       3     print(values)
# ----> 4 person("john",age=43,city="chennai",ph=1234567890)
#
# TypeError: person() got an unexpected keyword argument 'age'

# %%
def person(name,**values):
    print("name:",name)
    print(values)
person("john",age=43,city="chennai",ph=1234567890)

# %%
def person(name,**values):
    print('name',name)
    for i,j in values.items():
        print(i,j)
person('john',age=23,dept='cse',coll='mec')
# Out:
# name john
# age 23
# dept cse
# coll mec

# %%
def person(name,**values):
    print("name:",name)
    print(values.items())
    for i ,j in values.items():
        print(i,j)
person("john",age=43,city="chennai",ph=1234567890)
# Out:
# name: john
# dict_items([('age', 43), ('city', 'chennai'), ('ph', 1234567890)])
# age 43
# city chennai
# ph 1234567890

# %%
def person(name,**values):
    print("name:",name)
    print("age:",values['age'])
    print("city:",values['city'])
    print("ph:",values['ph'])
person("john",age=43,city="chennai",ph=1234567890)
# Out:
# name: john
# age: 43
# city: chennai
# ph: 1234567890
